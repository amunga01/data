# %% [markdown]
# <a href="https://colab.research.google.com/github/amunga01/data/blob/main/Apollo_Amunga_21_2168_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import mpl_toolkits
# %matplotlib inline
import matplotlib

# %%
path =  "https://github.com/amunga01/data/raw/main/paris.csv"
data = pd.read_csv(path)
data
# Out:
#    Unnamed: 0  squareMeters  numberOfRooms  hasYard  hasPool  floors  \
# 0           0         75523              3        0        1      63
# 1           1         80771             39        1        1      98
# 2           2         55712             58        0        1      19
# 3           3         32316             47        0        0       6
# 4           4         70429             19        1        1      90
# 5           5         39223             36        0        1      17
#
#    cityCode  numPrevOwners  made  hasStormProtector  garage  StorageeRoom  \
# 0      9373              8  2005                  1       5             0
# 1     39381              6  2015                  0       7             1
# 2     34457              8  2021                  0       4             1
# 3     27939              4  2012                  1       2             0
# 4     38045              7  1990                  0       5             1
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'squareMeters', 'numberOfRooms', 'hasYard', 'hasPool',
#        'floors', 'cityCode', 'numPrevOwners', 'made', 'hasStormProtector',
#        'garage', 'StorageeRoom', 'hasGuestRoom', 'price in pounds',
#        'prices in shillings(*1000000)', 'Kshs'],
#       dtype='object')

# %%
data.hist(bins=50,figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'squareMeters'}>,
#         <Axes: title={'center': 'numberOfRooms'}>,
#         <Axes: title={'center': 'hasYard'}>],
#        [<Axes: title={'center': 'hasPool'}>,
#         <Axes: title={'center': 'floors'}>,
#         <Axes: title={'center': 'cityCode'}>,
#         <Axes: title={'center': 'numPrevOwners'}>],
#        [<Axes: title={'center': 'made'}>,
#         <Axes: title={'center': 'hasStormProtector'}>,
#         <Axes: title={'center': 'garage'}>,
#         <Axes: title={'center': 'StorageeRoom'}>],
#        [<Axes: title={'center': 'hasGuestRoom'}>,
#         <Axes: title={'center': 'Kshs'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
plt.scatter(data.Kshs,data.squareMeters)
plt.title("Price vs Square Feet")
plt.xlabel('Prices in shillings*(1000000)')
plt.ylabel('SquareMeters',)
# Out:
# Text(0, 0.5, 'SquareMeters')

# %%
plt.scatter(data.Kshs,data.numberOfRooms)
plt.title("Price vs Number of Rooms")
plt.xlabel('Prices in shillings*(1000000)')
plt.ylabel('Number of rooms',)
# Out:
# Text(0, 0.5, 'Number of rooms')

# %%
plt.scatter(data.Kshs,data.hasGuestRoom)
plt.title("Price vs Guestroom")
plt.xlabel('Prices in shillings*(1000000)')
plt.ylabel('Guestroom',)
# Out:
# Text(0, 0.5, 'Guestroom')

# %%
plt.scatter(data.Kshs,data.hasPool)
plt.title("Price vs Pool")
plt.xlabel('prices in shillings*(1000000)')
plt.ylabel('Pool',)
# Out:
# Text(0, 0.5, 'Pool')

# %%
plt.scatter(data.Kshs,data.made)
plt.title("Price vs Year Made")
plt.xlabel('prices in shillings*(1000000)')
plt.ylabel('Year made',)
# Out:
# Text(0, 0.5, 'Year made')

# %%
plt.scatter((data['squareMeters']+data['basement']+data['hasGuestRoom']+data['hasPool']),data['Kshs'],)
plt.title("Prices with both basements,pool,guestroom and square feet")
plt.ylabel("squaremetres")
plt.xlabel("prices in shillings*(1000000)")
# Out:
# Text(0.5, 0, 'prices in shillings*(1000000)')

# %%
plt.scatter(data.cityCode,data.Kshs)
plt.title("Costly place by City code")
plt.ylabel("prices in shillings*(1000000)")
plt.xlabel("City Code")
# Out:
# Text(0.5, 0, 'City Code')

# %%
corr= data.corr()
sns.heatmap(corr)
# Out:
# <ipython-input-14-486505a44fda>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr= data.corr()
# <Axes: >

# %%
corr_matrix=data.corr()
corr_matrix["Kshs"].sort_values(ascending=False)
# Out:
# <ipython-input-39-532ac17ff150>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix=data.corr()
# Kshs                 1.000000
# squareMeters         0.999999
# garage               0.942117
# floors               0.910985
# hasPool              0.654988
# hasYard              0.645566
# numPrevOwners        0.602841
# StorageeRoom         0.548331
# hasGuestRoom         0.245614
# cityCode            -0.163782
# made                -0.310829
# numberOfRooms       -0.526500
# hasStormProtector   -0.548331
# Unnamed: 0          -0.630707
# Name: Kshs, dtype: float64

# %%
X=data[['squareMeters', 'numberOfRooms', 'hasYard', 'hasPool', 'floors', 'numPrevOwners', 'made', 'hasStormProtector', 'garage', 'StorageeRoom','hasGuestRoom']]
y=data['Kshs']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=1984)

# %%
X_train
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  numPrevOwners  made  \
# 0         75523              3        0        1      63              8  2005
# 1         80771             39        1        1      98              6  2015
# 3         32316             47        0        0       6              4  2012
# 4         70429             19        1        1      90              7  1990
#
#    hasStormProtector  garage  StorageeRoom  hasGuestRoom
# 0                  1       5             0             7
# 1                  0       7             1             2
# 3                  1       2             0             3
# 4                  0       5             1             4

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])

# %%
coeff_df
# Out:
#                    Coefficient
# squareMeters          0.016626
# numberOfRooms        -0.001896
# hasYard               0.000062
# hasPool              -0.000066
# floors                0.004033
# numPrevOwners        -0.000386
# made                 -0.000961
# hasStormProtector     0.000066
# garage                0.000054
# StorageeRoom         -0.000066
# hasGuestRoom         -0.000826

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test, predictions)

# %%
sns.distplot((y_test-predictions), bins=50)
# Out:
# <ipython-input-27-391f0a685db8>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot((y_test-predictions), bins=50)
# <Axes: xlabel='Kshs', ylabel='Density'>

# %%
import statsmodels.api as sm
X_train=sm.add_constant(X_train)
X_train.head()
# Out:
#    const  squareMeters  numberOfRooms  hasYard  hasPool  floors  \
# 0    1.0         75523              3        0        1      63
# 1    1.0         80771             39        1        1      98
# 3    1.0         32316             47        0        0       6
# 4    1.0         70429             19        1        1      90
#
#    numPrevOwners  made  hasStormProtector  garage  StorageeRoom  hasGuestRoom
# 0              8  2005                  1       5             0             7
# 1              6  2015                  0       7             1             2
# 3              4  2012                  1       2             0             3
# 4              7  1990                  0       5             1             4

# %%
nicer_OLS=sm.OLS(y_train,X_train).fit()
nicer_OLS.summary()
# Out:
# /usr/local/lib/python3.9/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /usr/local/lib/python3.9/dist-packages/statsmodels/regression/linear_model.py:1765: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.9/dist-packages/statsmodels/regression/linear_model.py:1765: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.9/dist-packages/statsmodels/regression/linear_model.py:1687: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
