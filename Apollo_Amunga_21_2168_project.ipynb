# %% [markdown]
# <a href="https://colab.research.google.com/github/amunga01/data/blob/main/Apollo_Amunga_21_2168_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import mpl_toolkits
# %matplotlib inline
import matplotlib

# %%
path =  "https://github.com/amunga01/data/raw/main/paris.csv"
data = pd.read_csv(path)
data
# Out:
#         Date  squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0   20221223         75523              3        0        1      63      9373
# 1   20210514         80771             39        1        1      98     39381
# 2   20201201         55712             58        0        1      19     34457
# 3   20220603         32316             47        0        0       6     27939
# 4   20220310         70429             19        1        1      90     38045
# 5   20230107         39223             36        0        1      17     39489
# 6   20220305         58682             10        1        1      99      6450
# 7   20230303         86929            100        1        0      11     98155
# 8   20221213         51522              3        0        0      61      9047
# 9   20221123         39686             42        0        0      15     71019
# 10  20221013         23563             21        0        1      90     91058
# 11  20221205         96470             74        1        0      21     92029
# 12  20220123         19127             31        1        0       5      7475
# 13  20220820         13087             44        1        0      77     40475
# 14  20220930         79770              3        0        1      69     54812
# 15  20220515         75985             60        1        0      67      6517
# 16  20220223         64169             88        0        1       6     61711
# 17  20220627         99371             31        1        1      16     96297
# 18  20221223         25966             37        1        1      17     22818
# 19  20220409         41792             43        1        1      10     80768
# 20  20220210         28795             64        1        1      50     97667
# 21  20220613         92383             12        0        0      78     71982
# 22  20220514         33279             64        1        0      65     91690
# 23  20220623         34782             47        0        0      73     35331
# 24  20220131         13386             51        0        0      90     87978
# 25  20220530         20883             56        0        0      54     85377
# 26  20220213         95121             46        0        1       3      9382
# 27  20220213          6071             72        1        0      14      8410
# 28  20220214         11844             43        0        0      55     46144
#
#     cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0               3              8  2005           0                  1
# 1               8              6  2015           1                  0
# 2               6              8  2021           0                  0
# 3              10              4  2012           0                  1
# 4               3              7  1990           1                  0
# 5               8              6  2012           0                  1
# 6              10              9  1995           1                  1
# 7               3              4  2003           1                  0
# 8               8              3  2012           1                  1
# 9               5              8  2021           1                  1
# 10              6              8  1993           1                  0
# 11              4              2  2011           1                  1
# 12              2              9  2008           0                  0
# 13              8              4  2004           1                  0
# 14             10              5  2018           0                  1
# 15              6              9  2009           1                  1
# 16              3              9  2011           1                  1
# 17              7              8  2013           1                  1
# 18              3              1  2016           0                  0
# 19              9              5  2017           1                  1
# 20              3              4  2009           1                  1
# 21              3              7  2000           0                  0
# 22              3              2  2019           1                  1
# 23              1              4  2020           0                  1
# 24              4              6  1993           0                  0
# 25              5              9  2018           0                  0
# 26              7              9  1994           0                  0
# 27              2              6  2003           1                  1
# 28              6              5  1993           1                  0
#
#     basement  attic  garage  hasStorageRoom  hasGuestRoom price in pounds  \
# 0       4313   9005     956               0             7  $7,559,081.50
# 1       3653   2436     128               1             2  $8,085,989.50
# 2       2937   8852     135               1             9  $5,574,642.10
# 3        659   7141     359               0             3  $3,232,561.20
# 4       8435   2429     292               1             4  $7,055,052.00
# 5       2009   4552     757               0             1  $3,926,647.20
# 6       5930   9453     848               0             5  $5,876,376.50
# 7       6326   4748     654               0            10  $8,696,869.30
# 8        632   5792     807               1             5  $5,154,055.20
# 9       5198   5342     591               1             3  $3,970,892.10
# 10       703    852     684               1            10  $2,366,397.30
# 11      5414   1172     716               1             9  $9,652,258.10
# 12      5387   4430     374               0             4  $1,914,688.80
# 13      1745    724     582               0             0  $1,320,803.40
# 14      8871   7117     240               0             7  $7,986,665.80
# 15      4878    281     384               1             5  $7,607,322.90
# 16      3054    129     726               0             9  $6,420,823.10
# 17      3258   6296     354               1             8  $9,944,705.30
# 18      8257   2557     162               0             6  $2,604,486.60
# 19      2950   9573     572               1             5  $4,187,667.70
# 20      9862   2666     330               1             0  $2,888,047.90
# 21      7507   9056     892               1             1  $9,244,344.00
# 22      2427    717     732               0             1  $3,333,351.90
# 23      9586   6604     822               0             2  $3,482,594.00
# 24      2885   1149     904               1             4  $1,342,509.30
# 25      9982   8142     670               1            10  $2,091,505.80
# 26       615   1221     328               0            10  $9,515,440.40
# 27      3306   3635     295               0             2    $612,471.30
# 28      5292   8233     395               0            10  $1,189,939.30
#
#    prices in shillings(*1000000)  Kshs
# 0                   Ksh 1,255.00  1255
# 1                   Ksh 1,343.00  1343
# 2                     Ksh 926.00   926
# 3                     Ksh 537.00   537
# 4                   Ksh 1,172.00  1172
# 5                     Ksh 652.00   652
# 6                     Ksh 976.00   976
# 7                   Ksh 1,444.00  1444
# 8                     Ksh 856.00   856
# 9                     Ksh 659.00   659
# 10                    Ksh 393.00   393
# 11                  Ksh 1,603.00  1603
# 12                    Ksh 318.00   318
# 13                    Ksh 219.00   219
# 14                  Ksh 1,326.00  1326
# 15                  Ksh 1,263.00  1263
# 16                  Ksh 1,066.00  1066
# 17                  Ksh 1,652.00  1652
# 18                    Ksh 432.00   432
# 19                    Ksh 695.00   695
# 20                    Ksh 479.00   479
# 21                  Ksh 1,535.00  1535
# 22                    Ksh 553.00   553
# 23                    Ksh 578.00   578
# 24                    Ksh 223.00   223
# 25                    Ksh 347.00   347
# 26                  Ksh 1,580.00  1580
# 27                    Ksh 101.00   101
# 28                    Ksh 197.00   197

# %%
data.columns
# Out:
# Index(['Date', 'squareMeters', 'numberOfRooms', 'hasYard', 'hasPool', 'floors',
#        'cityCode', 'cityPartRange', 'numPrevOwners', 'made', 'isNewBuilt',
#        'hasStormProtector', 'basement', 'attic', 'garage', 'hasStorageRoom',
#        'hasGuestRoom', 'price in pounds', 'prices in shillings(*1000000)',
#        'Kshs'],
#       dtype='object')

# %%
sns.pairplot(data)

# %%
data['numberOfRooms'].value_counts().plot(kind='bar')
plt.title('Number of Rooms')
plt.xlabel('Rooms')
plt.ylabel('count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(data.Kshs,data.squareMeters)
plt.title("Price vs Square Feet")
plt.xlabel('Prices in shillings*(1000000)')
plt.ylabel('SquareMeters',)
# Out:
# Text(0, 0.5, 'SquareMeters')

# %%
plt.scatter(data.Kshs,data.numberOfRooms)
plt.title("Price vs Number of Rooms")
plt.xlabel('Prices in shillings*(1000000)')
plt.ylabel('Number of rooms',)
# Out:
# Text(0, 0.5, 'Number of rooms')

# %%
plt.scatter(data.Kshs,data.hasGuestRoom)
plt.title("Price vs Guestroom")
plt.xlabel('Prices in shillings*(1000000)')
plt.ylabel('Guestroom',)
# Out:
# Text(0, 0.5, 'Guestroom')

# %%
plt.scatter(data.Kshs,data.hasPool)
plt.title("Price vs Pool")
plt.xlabel('prices in shillings*(1000000)')
plt.ylabel('Pool',)
# Out:
# Text(0, 0.5, 'Pool')

# %%
plt.scatter(data.Kshs,data.made)
plt.title("Price vs Year Made")
plt.xlabel('prices in shillings*(1000000)')
plt.ylabel('Year made',)
# Out:
# Text(0, 0.5, 'Year made')

# %%
plt.scatter((data['squareMeters']+data['basement']+data['hasGuestRoom']+data['hasPool']),data['Kshs'],)
plt.title("Prices with both basements,pool,guestroom and square feet")
plt.ylabel("squaremetres")
plt.xlabel("prices in shillings*(1000000)")
# Out:
# Text(0.5, 0, 'prices in shillings*(1000000)')

# %%
plt.scatter(data.cityCode,data.Kshs)
plt.title("Costly place by City code")
plt.ylabel("prices in shillings*(1000000)")
plt.xlabel("City Code")
# Out:
# Text(0.5, 0, 'City Code')

# %%
corr= data.corr()
sns.heatmap(corr)
# Out:
# <ipython-input-138-486505a44fda>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr= data.corr()
# <Axes: >

# %%
X=data[['squareMeters', 'numberOfRooms', 'hasYard', 'hasPool', 'floors', 'numPrevOwners', 'made', 'hasStormProtector', 'basement', 'attic', 'garage', 'hasStorageRoom','hasGuestRoom']]
y=data['Kshs']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.40, random_state=101)

# %%
X_train
# Out:
#     squareMeters  numberOfRooms  hasYard  hasPool  floors  numPrevOwners  \
# 18         25966             37        1        1      17              1
# 21         92383             12        0        0      78              7
# 12         19127             31        1        0       5              9
# 5          39223             36        0        1      17              6
# 14         79770              3        0        1      69              5
# 0          75523              3        0        1      63              8
# 20         28795             64        1        1      50              4
# 4          70429             19        1        1      90              7
# 8          51522              3        0        0      61              3
# 13         13087             44        1        0      77              4
# 9          39686             42        0        0      15              8
# 15         75985             60        1        0      67              9
# 28         11844             43        0        0      55              5
# 23         34782             47        0        0      73              4
# 6          58682             10        1        1      99              9
# 17         99371             31        1        1      16              8
# 11         96470             74        1        0      21              2
#
#     made  hasStormProtector  basement  attic  garage  hasStorageRoom  \
# 18  2016                  0      8257   2557     162               0
# 21  2000                  0      7507   9056     892               1
# 12  2008                  0      5387   4430     374               0
# 5   2012                  1      2009   4552     757               0
# 14  2018                  1      8871   7117     240               0
# 0   2005                  1      4313   9005     956               0
# 20  2009                  1      9862   2666     330               1
# 4   1990                  0      8435   2429     292               1
# 8   2012                  1       632   5792     807               1
# 13  2004                  0      1745    724     582               0
# 9   2021                  1      5198   5342     591               1
# 15  2009                  1      4878    281     384               1
# 28  1993                  0      5292   8233     395               0
# 23  2020                  1      9586   6604     822               0
# 6   1995                  1      5930   9453     848               0
# 17  2013                  1      3258   6296     354               1
# 11  2011                  1      5414   1172     716               1
#
#     hasGuestRoom
# 18             6
# 21             1
# 12             4
# 5              1
# 14             7
# 0              7
# 20             0
# 4              4
# 8              5
# 13             0
# 9              3
# 15             5
# 28            10
# 23             2
# 6              5
# 17             8
# 11             9

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])

# %%
coeff_df
# Out:
#                    Coefficient
# squareMeters          0.016619
# numberOfRooms         0.006080
# hasYard               0.366901
# hasPool               0.536795
# floors                0.012913
# numPrevOwners         0.001867
# made                  0.006076
# hasStormProtector    -0.430639
# basement             -0.000088
# attic                -0.000004
# garage               -0.000704
# hasStorageRoom       -0.146088
# hasGuestRoom         -0.025471

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test, predictions)

# %%
sns.distplot((y_test-predictions), bins=50)
# Out:
# <ipython-input-18-391f0a685db8>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot((y_test-predictions), bins=50)
# <Axes: xlabel='Kshs', ylabel='Density'>
